# %% [markdown]
# ![Linear1.png](attachment:Linear1.png)

# %% [markdown]
# ![Linear2.png](attachment:Linear2.png)

# %% [markdown]
# ![Linear3.png](attachment:Linear3.png)

# %% [markdown]
# ![Linear4.png](attachment:Linear4.png)

# %% [markdown]
# ![Linear5.png](attachment:Linear5.png)

# %% [markdown]
# ![Linear6.png](attachment:Linear6.png)

# %% [markdown]
# ![Linear7.png](attachment:Linear7.png)
